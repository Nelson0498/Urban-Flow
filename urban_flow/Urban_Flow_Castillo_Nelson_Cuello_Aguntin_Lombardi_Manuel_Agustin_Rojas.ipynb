# %% [markdown]
# # Trabajo Práctico Integrador

# %% [markdown]
# ## Urban Flow

# %% [markdown]
# ## Integrantes del grupo:
#
# * Castillo Nelson
# * Cuello Agustin
# * Lombardi Manuel
# * Rojas Agustin

# %% [markdown]
# ## Sprint 1

# %% [markdown]
# ## Consideraciones Generales e Importantes
#
# - Desarrollo base: Los puntos solicitados son la base del trabajo práctico. Es posible la ampliación sin restricciones del mismo.
#
# - Organización del Notebook:
#   - Agregar antes del ejercicio 01 una celda donde se importan todas librerías necesarias.
#
#   - Utilizar un título para cada celda y escribir cada funcionalidad en una celda con título. Tener en cuenta agrupar las funcionalidades afines.

# %% [markdown]
# ## Versionado y Trabajo en Equipo
#
# - La entrega puede entregarse en grupos de máximo 6 personas (mínimo 1 / máximo 6) y la defensa es individual. Los grupos deben mantenerse a lo largo del trabajo integrador.
#
# - Se debe considerar que es un trabajo en equipo y que cualquiera de los integrantes puede realizar modificaciones para cada día de trabajo.
#
# - Control de Versiones: Utilizar herramientas de versionado. Vincularlo por token a tu cuenta personal de versionado en la nube.
#
# - Colaboradores: Brindar acceso al repositorio a las siguientes cuentas:
#
#   - lcd-sa182@ugr.edu.ar
#
#   - fpasinato@ugr.edu.ar
#
# - Changelog: Cada ejercicio/punto del trabajo práctico es considerado como un día distinto de trabajo. Debe quedar constancia en un archivo CHANGELOG.md de los cambios generados cada día.
#
# - Agregar una variable llamada desactivar_git_push que solamente me permita desactivar los "git push".
#
# - El archivo README.md debe contener el sprint en el que nos encontramos y debe contener:
#   - El objetivo.
#   - La introducción y el contexto del sprint de trabajo.

# %% [markdown]
# ## Criterios de evaluación
#
# - Funcionalidad:
#
#   - El código debe ejecutar sin errores al ejecutar "Ejecutar todo" (Ctrl+F9).
#
#   - Se debe implementar la totalidad de las funcionalidades solicitadas.
#
#   - La lógica del programa debe ser correcta y consistente.
#
#   - Utilización de librerías acorde a los problemas a resolver.
#
#   - Recordar antes de entregar de validar el notebook con los siguientes pasos. Ir al menú Runtine/Ejecutar -> Restart session and run all/Reiniciar la sessión y ejecutar todo
#
# - Claridad y organización:
#
#   - El código debe estar bien organizado y dividido.
#
#   - Utilizar diferentes celdas de código para resolver cada solicitud/punto dentro de un ejercicio específico con su comentario "title" correspondiente a la solución implementada.
#
#   - Se deben utilizar nombres de variables que describan su contenido/función.
#
#   - Se debe agregar comentarios explicativos y necesarios según estandares.
#
#   - Todos los imports deben ubicarse en la primer celda de ejecución arriba de la descripción del "Ejercicio 01".
#
#   - No se admite la sentencia "git add ." para simplificar el traceo.
#
#   - No se admiten comentarios innecesarios dentro del código. Solo comentar funciones, clases, métodos y propiedades de clase.
#
# - Estilo y presentación:
#
#   - Se debe usar una indentación consistente y un formato de código adecuado.
#
#   - Se deben evitar comentarios redundantes o irrelevantes.
#
#   - Se debe presentar el código de forma ordenada y profesional.
#
#   - Se debe utilizar [type hints](https://docs.python.org/3/library/typing.html).
#
#   - Se deben utilizar comentarios según el [pep8](https://peps.python.org/pep-0008/).
#
# - Herramientas:
#
#   - Utilizar principalmente librerías vistas durante la cursada. No se admiten librerías similares a las vistas en la materia.
#
#   - Utilizar librerías extras con criterios fundamentados, es decir, no utilizar por utilizar.
#
#   - Indentar a 2 espacios y cortar a 80 caracteres según estandares.
#
#   - No se puede utilizar gdrive.
#
#   - No se pueden utilizar herramientas alternativas a las vistas durante la cursada.

# %% [markdown]
# ## Condiciones de Entrega
# - Formato de Archivo: Los estudiantes deberán enviar un archivo con extensión .ipynb.
#
# - Nomenclatura: El nombre original del archivo debe reemplazar los valores indicados. Ejemplo: 0X_Price_Manager-Apellidos_Nombres.ipynb.
#
# - Estado de la entrega:
#   - Deberá entregarse ejecutado y con los datos precargados.
#   - Deberá entregarse el desarrollo sobre una copia de la plantilla original.
#
# - Canal de Entrega: La entrega se realiza en el aula virtual y solo se aceptan archivos (cualquier otra forma se considerará inválida). Solo se recibirán trabajos por correo adjunto a lcd-sa182@ugr.edu.ar si el plazo en la plataforma ha finalizado. No se aceptarán enlaces sueltos.

# %% [markdown]
# ## Recomendaciones y Consecuencias del Incumplimiento
# - Recomendaciones: Comenzar a trabajar con suficiente antelación. Leer y comprender el enunciado en su totalidad. Realizar consultas ante dudas al correo: lcd-sa182@ugr.edu.ar o fpasinato@ugr.edu.ar. La entrega en tiempo y forma es fundamental.
#
# - Incumplimiento: Los trabajos que no cumplan con los requisitos no serán tomados en cuenta como nota final. Solo serán corregidos y evaluados con nota para la devolución correspondiente. Se considera incumplimiento a:
#
#   - Entregas fuera de término.
#
#   - Trabajos que no se entreguen sobre la plantilla de trabajo estipulada.
#
#   - Trabajos que no se ejecuten completos (que contengan errores intermedios al dar "Ejecutar todo").

# %% [markdown]
# ---

# %% [markdown]
# ## Objetivo
#
# El objetivo principal de este proyecto es aplicar los conocimientos adquiridos en para el versionado de código, la organización, limpieza del código y la utilización de pandas.

# %% [markdown]
# ## Introducción y Contexto del problema

# %% [markdown]
# ### Sprint 1
#
# La localidad llamada Vaalserberg de Bélgica se encuentra en la zona fronteriza y limita con los paises de Países Bajos y Alemania. Esta localidad cuenta con un sistema de radares urbanos para la detección de infracciones por exceso de velocidad. Los registros históricos provienen de sistemas heredados, el cuál presenta errores de formato, faltante de datos generando registros inconsistentes en el nuevo sistema.
#
# Debemos analizar y depurar los datos de viejo sistema para obtener información relevante sobre las infracciones y de está forma en el futuro poder incorporar los datos al nuevo sistema sin inconsistencias.
#
# Descargar el dataset [speeding fines](https://raw.githubusercontent.com/HAD141/datasets/refs/heads/main/TrabajosPracticos/urban_flow/speeding_fines.csv) https://raw.githubusercontent.com/HAD141/datasets/refs/heads/main/TrabajosPracticos/urban_flow/speeding_fines.csv
#
# El dataset contiene información histórica de multas por exceso de velocidad y presenta errores que deberán ser tratados para evitar inconsistencias.

# %% [markdown]
# ---

# %%
# Título: Importación de librerías y configuración de variables globales
import os
import shutil
import pandas as pd
import matplotlib.pyplot as plt
from typing import List
from google.colab import userdata, files

desactivar_git_push: bool = False

GIT_TOKEN: str = userdata.get('GIT_TOKEN')
GIT_USER: str = "Nelson0498"
GIT_REPO: str = "Urban-Flow"
GIT_EMAIL: str = "castillonelsonramiro3@email.com"
GIT_NAME: str = "Nelson Castillo"

# %% [markdown]
# ## Ejercicio 01
#
# > Puntos: 1
#
# Inicialización y configuración de la herramienta de versionado. Vamos a trabajar sobre la rama llamada "Sprint_1".
#
# La estructura de directorios es:
#
# ```
# ├── urban_flow
# │   ├── data
# │   │   ├── interim (almacena dataset procesados de pasos intermedios)
# │   │   │   ├── plots
# │   │   ├── processed (almacena dataset procesados finales para entregar a otra aplicación)
# │   │   ├── raw (almacena los dataset en crudo, sin procesar)
# ```

# %%
# Título: Ejercicio 01 - Creación de la estructura de directorios

def crear_directorios_proyecto() -> None:
  """
  Crea la estructura de directorios base para el proyecto urban_flow.

  Args:
    Ninguno.

  Returns:
    None: Crea carpetas en el sistema operativo.
  """
  directorios: List[str] = [
    "urban_flow/data/raw",
    "urban_flow/data/interim/plots",
    "urban_flow/data/processed"
  ]

  for directorio in directorios:
    os.makedirs(directorio, exist_ok=True)
    print(f"Directorio inicializado: {directorio}")


crear_directorios_proyecto()
# Out:
# Directorio inicializado: urban_flow/data/raw
# Directorio inicializado: urban_flow/data/interim/plots
# Directorio inicializado: urban_flow/data/processed

# %%
# Título: Ejercicio 01 - Generación de README.md y CHANGELOG.md

def crear_archivos_documentacion() -> None:
  """
  Genera los archivos README.md y CHANGELOG.md con la información
  del Sprint 1 y el equipo de trabajo.

  Args:
    Ninguno.

  Returns:
    None: Crea archivos en disco.
  """
  contenido_readme: str = """# Proyecto Urban Flow

**Equipo de Trabajo:**
- Cuello Agustin
- Castillo Nelson
- Rojas Agustin
- Lombardi Manuel

## Sprint 1

### Objetivo
Aplicar los conocimientos adquiridos para el versionado de código, la organización, limpieza del código y la utilización de pandas.

### Contexto
La localidad llamada Vaalserberg de Bélgica se encuentra en la zona fronteriza y limita con los paises como Países Bajos y Alemania. Esta localidad cuenta con un sistema de radares urbanos para la detección de infracciones por exceso de velocidad. Los registros históricos provienen de sistemas heredados, el cuál presenta errores de formato, faltante de datos generando registros inconsistentes en el nuevo sistema. Debemos analizar y depurar los datos del viejo sistema.
"""

  contenido_changelog: str = """# Changelog

Todas las modificaciones notables de este proyecto se documentarán en este archivo.

## [Día 1] - Ejercicio 01
- Inicialización del repositorio y configuración de Git.
- Creación de la rama Sprint_1.
- Estructuración de directorios (data/raw, data/interim, etc.).
- Creación de README.md y CHANGELOG.md.
"""

  with open("README.md", "w", encoding="utf-8") as f:
    f.write(contenido_readme)

  with open("CHANGELOG.md", "w", encoding="utf-8") as f:
    f.write(contenido_changelog)

  print("Archivos de documentación creados exitosamente.")

crear_archivos_documentacion()
# Out:
# Archivos de documentación creados exitosamente.

# %%
# Título: Ejercicio 01 - Descarga de datos crudos (Raw Data)

def descargar_dataset_fines() -> None:
  """
  Descarga el dataset de multas de velocidad desde GitHub y lo
  almacena físicamente en la carpeta raw.

  Args:
    Ninguno.

  Returns:
    None: Guarda el archivo CSV en disco.
  """
  url_datos: str = (
    "https://raw.githubusercontent.com/HAD141/datasets/refs/heads/main/"
    "TrabajosPracticos/urban_flow/speeding_fines.csv"
  )
  ruta_destino: str = "urban_flow/data/raw/speeding_fines.csv"

  try:
    df_crudo = pd.read_csv(url_datos)
    df_crudo.to_csv(ruta_destino, index=False)
    print(f"Dataset descargado y guardado en: {ruta_destino}")
  except Exception as e:
    print(f"Error al descargar o guardar el dataset: {e}")


descargar_dataset_fines()
# Out:
# Dataset descargado y guardado en: urban_flow/data/raw/speeding_fines.csv

# %%
# Título: Ejercicio 01 - Configuración de Git y Primer Commit

def ejecutar_versionado() -> None:
  """
  Inicializa Git, configura credenciales, crea la rama y realiza el commit inicial.

  Args:
    Ninguno. Utiliza variables globales.

  Returns:
    None: Ejecuta comandos del sistema.
  """
  if not os.path.exists(".git"):
    os.system("git init")

  os.system(f'git config --global user.email "{GIT_EMAIL}"')
  os.system(f'git config --global user.name "{GIT_NAME}"')

  os.system("git checkout -b Sprint_1 || git checkout Sprint_1")

  os.system("git add README.md")
  os.system("git add CHANGELOG.md")
  os.system("git add urban_flow/")

  os.system(
    'git commit -m "feat: Ejercicio 01 - Estructura inicial y configuración Sprint 1"'
  )

  if not desactivar_git_push and GIT_TOKEN:
    remote_url: str = (
      f"https://{GIT_TOKEN}@github.com/"
      f"{GIT_USER}/{GIT_REPO}.git"
    )
    os.system("git remote remove origin")
    os.system(f"git remote add origin {remote_url}")
    os.system("git push -u origin Sprint_1")
    print("Push realizado con éxito a la rama Sprint_1.")
  else:
    print(
      "El commit local se realizó. La subida remota (Push) "
      "está desactivada o no se configuró el token."
    )


ejecutar_versionado()
# Out:
# Push realizado con éxito a la rama Sprint_1.

# %% [markdown]
# ## Ejercicio 02
#
# > Puntos: 1
#
# Los desarrollos que deben realizar son:
#
# - Descargar el dataset raw original y almacenarlo en `urban_flow/data/raw`.
#
# - Mostrar las 5 primeras filas.
#
# - Analizar tipos de datos
#
# - Contar los valores nulos.

# %%
# Título: Ejercicio 02 - Carga del dataset y visualización de las primeras filas

def cargar_y_mostrar_datos() -> pd.DataFrame:
  """
  Carga el dataset crudo desde la carpeta raw y muestra las primeras filas.

  Args:
    Ninguno.

  Returns:
    pd.DataFrame: Retorna el DataFrame cargado en memoria.
  """
  ruta_archivo: str = "urban_flow/data/raw/speeding_fines.csv"

  if not os.path.exists(ruta_archivo):
    raise FileNotFoundError(f"No se encontró el archivo en {ruta_archivo}")

  df_fines_raw: pd.DataFrame = pd.read_csv(ruta_archivo)

  print("Primeras 5 filas del dataset:")
  print(df_fines_raw.head())

  return df_fines_raw


df_fines_raw: pd.DataFrame = cargar_y_mostrar_datos()
# Out:
# Primeras 5 filas del dataset:
#    multa_id    patente         fecha          hora  velocidad_registrada  \
# 0         1    FD 1475    24/09/2021      09:01 AM                   NaN
# 1         2   0695 DVH    19/05/2020         18:01                   NaN
# 2         3   WU 341 A    2022/07/17      09:01 AM                 107.0
# 3         4   GN64 OTP  invalid_date  invalid_hour                   NaN
# 4         5  BX 55 DOG    2021/01/21  invalid_hour                  94.0
#
#    velocidad_maxima         ubicacion radar_id estado_multa
# 0                60  Av. Siempre Viva      R01      APELADA
# 1                40   Av Siempre Viva      NaN      APELADA
# 2                60     AV LIBERTADOR      R03       PAGADA
# 3                60            Ruta 9      NaN      APELADA
# 4                60  Av. Siempre Viva      NaN        ERROR

# %%
# Título: Ejercicio 02 - Análisis de tipos de datos y valores nulos

def analizar_metadatos_dataset(df: pd.DataFrame) -> None:
  """
  Analiza e imprime los tipos de datos de cada columna y la cantidad
  de valores nulos.

  Args:
    df (pd.DataFrame): DataFrame a inspeccionar.

  Returns:
    None: Imprime resultados por consola.
  """
  print("Tipos de datos por columna:")
  print("-" * 40)
  print(df.dtypes)
  print()

  print("Conteo de valores nulos por columna:")
  print("-" * 40)
  nulos_por_columna: pd.Series = df.isnull().sum()
  print(nulos_por_columna)


analizar_metadatos_dataset(df_fines_raw)
# Out:
# Tipos de datos por columna:
# ----------------------------------------
# multa_id                  int64
# patente                  object
# fecha                    object
# hora                     object
# velocidad_registrada    float64
# velocidad_maxima          int64
# ubicacion                object
# radar_id                 object
# estado_multa             object
# dtype: object
#
# Conteo de valores nulos por columna:
# ----------------------------------------
# multa_id                   0
# patente                   50
# fecha                      0
# hora                       0
# velocidad_registrada    1957
# velocidad_maxima           0
# ubicacion                  0
# radar_id                1002
# estado_multa               0
# dtype: int64

# %%
def turno_agustin_commit() -> None:
    """
    Configuracion de archivo , actualizacion de Changelelog y primer comit Agustin Cuello

    """
    print("--- REGISTRANDO TRABAJO DE Agustin Cuello ---")

    os.system('git config --global user.email "agustin_cuelloluna01@hotmail.com"')
    os.system('git config --global user.name "agustincl01"')



    print("\nPor favor, selecciona tu archivo 'notebook_sprint_1.ipynb':")
    archivo_subido = files.upload()

    if not archivo_subido:
        print("❌ No se subió ningún archivo. Proceso cancelado.")
        return

    nombre_archivo = list(archivo_subido.keys())[0]
    ruta_destino = f"urban_flow/{nombre_archivo}"


    shutil.move(nombre_archivo, ruta_destino)
    print(f"✅ Archivo guardado en: {ruta_destino}")


    nuevo_registro: str = """
## [Día 2] - Ejercicio 02 (Autor: Agustín Cuello)
- Subida de notebook individual.
- Análisis exploratorio de datos resuelto.
"""
    with open("CHANGELOG.md", "a", encoding="utf-8") as f:
        f.write(nuevo_registro)
    print("✅ CHANGELOG.md actualizado.")


    os.system(f"git add {ruta_destino}")
    os.system("git add CHANGELOG.md")
    os.system('git commit -m "feat: Ejercicio 02 - Análisis exploratorio resuelto por Agustin Cuello"')
    print("✅ Commit local realizado con éxito a nombre de Agustín Cuello.")


    if not desactivar_git_push and GIT_TOKEN:
        os.system("git push origin Sprint_1")
        print("🚀 Push realizado con éxito a GitHub.")
    else:
        print("⚠️ El Push automático está desactivado.")


turno_agustin_commit()
# Out:
# --- REGISTRANDO TRABAJO DE Agustin Cuello ---
#
# Por favor, selecciona tu archivo 'notebook_sprint_1.ipynb':
#      <input type="file" id="files-df120e42-fd58-4d6b-b74f-b1f981965357" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-df120e42-fd58-4d6b-b74f-b1f981965357">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %% [markdown]
# ## Ejercicio 03
#
# > Puntos: 2
#
# Utilizando Pandas:
#
# - Normalizar las de fechas con el formato 'YYYY-MM-DD', en caso de fechas inválidas completar con la fecha `1932-01-01`. Mostrar las 10 primeras fechas.
#
# - Normalizar los horas al formato de 24hs, las horas inválidas se procesaran como `00:00`. Mostrar las 10 primeras horas.
#
# - Normalizar las ubicaciones. Quitar caracteres especiales y pasar todo a mayúsculas. Mostrar las 10 primeras ubicaciones.
#
# - Limpiar y normalizar las patentes, en caso de error completar con pd.NA (no disponible/not available). Quitar caracteres especiales y pasar todo a mayúsculas. Mostrar las 10 últimas patentes.
#
# - Eliminar las filas que posean valores relevantes para las multas y que se encuentren vacios. Mostrar la cantidad de registros eliminados y cuales son las columnas que se observaron utilizando la leyenda
# ```
# Se eliminaron X filas.
# Las columnas observadas son:
#  - XXX
#  - XXX
#  - ...
# ```
#
# - Detectar y eliminar los outliers. Mostrar la cantidad de registros eliminados y cuales son las columnas que se observaron utilizando la leyenda
# ```
# Se eliminaron X filas.
# Las columnas observadas son:
#  - XXX
#  - XXX
#  - ...
# ```
#
# - Crear la columna `exceso_velocidad_real` y calcularla. El exceso de velocidad real es la diferencia entre velocidad_registrada y la velocidad_maxima. Mostrar las primeras 10 patentes y su exceso de velocidad real.
#
# - Crear la columna `exceso_velocidad` y calcularla. El exceso de velocidad es la diferencia entre velocidad_registrada y la velocidad_maxima más un 5 porciento de la velocidad máxima. Mostrar las primeras 10 patentes y su exceso de velocidad.
#
# - Eliminar las filas que no cometieron infracciones según el exceso de velocidad.Mostrar cuantas filas se eliminaron con la leyenda
# ```
# Se eliminaron X filas.
# ```
#
# - Guardar el dataset limpio en `urban_flow/data/interim/speeding_fines.csv`

# %%
# Título: Ejercicio 03 - Normalización de Fechas y Horas (Editado por Manu Lombardi)

def normalizar_datos_temporales(df: pd.DataFrame) -> pd.DataFrame:
  """
  Normaliza las columnas de fecha y hora del sistema heredado.
  Las fechas inválidas se establecen en 1932-01-01 y las horas en 00:00.

  Args:
    df (pd.DataFrame): DataFrame con columnas 'fecha' y 'hora'.

  Returns:
    pd.DataFrame: DataFrame con formatos temporales estandarizados.
  """

  fechas: pd.Series = pd.to_datetime(df['fecha'], errors='coerce', dayfirst=True)
  df['fecha'] = fechas.fillna(
    pd.Timestamp('1932-01-01')
  ).dt.strftime('%Y-%m-%d')

  print("Primeras 10 fechas normalizadas:")
  print(df['fecha'].head(10))
  print("-" * 40)
  print()


  horas: pd.Series = pd.to_datetime(
    df['hora'], format='mixed', errors='coerce'
  )
  df['hora'] = horas.fillna(
    pd.Timestamp('1900-01-01 00:00')
  ).dt.strftime('%H:%M')

  print("Primeras 10 horas normalizadas:")
  print(df['hora'].head(10))

  return df

df_fines_raw = normalizar_datos_temporales(df_fines_raw)
# Out:
# Primeras 10 fechas normalizadas:
# 2     1932-01-01
# 4     1932-01-01
# 7     1932-01-01
# 9     1932-01-01
# 11    1932-01-01
# 12    1932-01-01
# 16    1932-01-01
# 20    1932-01-01
# 21    1932-01-01
# 23    1932-01-01
# Name: fecha, dtype: object
# ----------------------------------------
#
# Primeras 10 horas normalizadas:
# 2     00:00
# 4     00:00
# 7     08:01
# 9     14:01
# 11    00:00
# 12    18:01
# 16    00:00
# 20    08:01
# 21    00:00
# 23    08:01
# Name: hora, dtype: object

# %%
def commit_nelson_ejercicio_03() -> None:
    """
    Subida de Archivo del ejercicio de Normalización de Horas y Fechas por Nelson.
    Ajustado a la estructura de directorios correcta.
    """
    print("--- REGISTRANDO TRABAJO DE NELSON CASTILLO ---")

    os.system('git config --global user.email "castillonelsonramiro3@email.com"')
    os.system('git config --global user.name "Nelson0498"')
    print(" Identidad configurada como Nelson0498")

    nuevo_registro: str = """
## [Día 3] - Ejercicio 03 (Autor: Nelson Castillo)
- Implementación de la función normalizar_datos_temporales.
- Normalización de fechas al formato 'YYYY-MM-DD' (errores a 1932-01-01).
- Normalización de horas al formato de 24hs (errores a 00:00).
- Limpieza inicial de ubicaciones y patentes.
"""

    with open("CHANGELOG.md", "a", encoding="utf-8") as f:
        f.write(nuevo_registro)
    print(" CHANGELOG.md actualizado con la lógica de Nelson.")


    os.system("git add CHANGELOG.md")
    os.system("git add urban_flow/")


    os.system('git commit -m "feat: Ejercicio 03 - Lógica de normalización de fechas y horas por Nelson"')


    if not desactivar_git_push and GIT_TOKEN:
        os.system("git push origin Sprint_1")
        print(" Trabajo de Nelson subido con éxito a la rama Sprint_1.")
    else:
        print(" Commit local realizado. El Push está desactivado.")

commit_nelson_ejercicio_03()

# %%
def commit_manu_ejercicio_03() -> None:
    print("--- REGISTRANDO APORTE TÉCNICO DE MANUEL LOMBARDI ---")


    os.system('git config --global user.email "manuellombardi1306@gmail.com"')
    os.system('git config --global user.name "ML13-DEV"')
    print("✅ Identidad configurada como Manuel Lombardi")


    nuevo_registro: str = """
## [Día 3] - Ejercicio 03 (Corrección: Manuel Lombardi)
- Optimización de la función normalizar_datos_temporales.
- Se agregó `dayfirst=True` para corregir la advertencia de ambigüedad en fechas.
- Se implementó `format='mixed'` para procesar horas en múltiples formatos.
"""
    with open("CHANGELOG.md", "a", encoding="utf-8") as f:
        f.write(nuevo_registro)
    print("✅ CHANGELOG.md (raíz) actualizado con la lógica de Manu.")


    os.system("git add CHANGELOG.md")
    os.system("git add urban_flow/")


    os.system('git commit -m "fix: Ejercicio 03 - Optimización de advertencias y horas por Manu Lombardi"')


    if not desactivar_git_push and GIT_TOKEN:
        os.system("git push origin Sprint_1")
        print("🚀 ¡Trabajo de Manu subido con éxito a GitHub!")
    else:
        print("✅ Commit local realizado. El Push está desactivado.")

commit_manu_ejercicio_03()
# Out:
# --- REGISTRANDO APORTE TÉCNICO DE MANUEL LOMBARDI ---
# ✅ Identidad configurada como Manuel Lombardi
# ✅ CHANGELOG.md (raíz) actualizado con la lógica de Manu.
# 🚀 ¡Trabajo de Manu subido con éxito a GitHub!

# %%
# Título: Ejercicio 03 - Normalización de Ubicaciones y Patentes

def normalizar_cadenas(df: pd.DataFrame) -> pd.DataFrame:
  """
  Limpia las cadenas de texto en ubicaciones y patentes eliminando
  caracteres especiales y pasando a mayúsculas.

  Args:
    df (pd.DataFrame): DataFrame a limpiar.

  Returns:
    pd.DataFrame: DataFrame con strings normalizados.
  """
  df['ubicacion'] = df['ubicacion'].fillna('').str.replace(
    r'[^A-Za-z0-9 ]', '', regex=True
  ).str.upper()

  print("Primeras 10 ubicaciones:")
  print(df['ubicacion'].head(10))
  print("-" * 40)

  df['patente'] = df['patente'].fillna('').str.replace(
    r'[^A-Za-z0-9]', '', regex=True
  ).str.upper()

  df['patente'] = df['patente'].replace('', pd.NA)

  print("Últimas 10 patentes:")
  print(df['patente'].tail(10))

  return df


df_fines_raw = normalizar_cadenas(df_fines_raw)
# Out:
# Primeras 10 ubicaciones:
# 0    AV SIEMPRE VIVA
# 1    AV SIEMPRE VIVA
# 2      AV LIBERTADOR
# 3             RUTA 9
# 4    AV SIEMPRE VIVA
# 5    AV SIEMPRE VIVA
# 6      AV LIBERTADOR
# 7    AV SIEMPRE VIVA
# 8    AV SIEMPRE VIVA
# 9      AV LIBERTADOR
# Name: ubicacion, dtype: object
# ----------------------------------------
# Últimas 10 patentes:
# 3990    NHZ1002
# 3991    MX60NZA
# 3992     831MDB
# 3993     M20CPR
# 3994      BM351
# 3995    MPX9357
# 3996     831MDB
# 3997     BB8986
# 3998    8B90638
# 3999    691XC80
# Name: patente, dtype: object

# %%
# Título: Ejercicio 03 - Tratamiento de Inconsistencias (Nulos y Outliers)

def tratar_inconsistencias(df: pd.DataFrame) -> pd.DataFrame:
  """
  Elimina filas con nulos en columnas relevantes y remueve outliers
  de velocidad utilizando el método IQR.

  Args:
    df (pd.DataFrame): DataFrame a limpiar.

  Returns:
    pd.DataFrame: DataFrame sin nulos críticos ni outliers.
  """
  cols_obs: List[str] = [
    'fecha',
    'patente',
    'velocidad_registrada',
    'velocidad_maxima'
  ]

  total_antes: int = len(df)
  df = df.dropna(subset=cols_obs)
  eliminados_nulos: int = total_antes - len(df)

  print(f"Se eliminaron {eliminados_nulos} filas.")
  print("Las columnas observadas son:")
  for col in cols_obs:
    print(f" - {col}")
  print("-" * 40)

  q1: float = df['velocidad_registrada'].quantile(0.25)
  q3: float = df['velocidad_registrada'].quantile(0.75)
  iqr: float = q3 - q1

  limite_inf: float = q1 - 1.5 * iqr
  limite_sup: float = q3 + 1.5 * iqr

  df_filtrado: pd.DataFrame = df[
    (df['velocidad_registrada'] >= limite_inf) &
    (df['velocidad_registrada'] <= limite_sup)
  ]

  eliminados_out: int = len(df) - len(df_filtrado)

  print(f"Se eliminaron {eliminados_out} filas.")
  print("Las columnas observadas son:")
  print(" - velocidad_registrada")

  return df_filtrado


df_fines_raw = tratar_inconsistencias(df_fines_raw)
# Out:
# Se eliminaron 1982 filas.
# Las columnas observadas son:
#  - fecha
#  - patente
#  - velocidad_registrada
#  - velocidad_maxima
# ----------------------------------------
# Se eliminaron 0 filas.
# Las columnas observadas son:
#  - velocidad_registrada

# %%
def commit_agustin_rojas_ejercicio_03() -> None:
    print("--- REGISTRANDO APORTE TÉCNICO DE AGUSTÍN ROJAS ---")


    os.system('git config --global user.email "agu.rojas98@gmail.com"')
    os.system('git config --global user.name "ARojas998"')
    print("✅ Identidad configurada como ARojas998 (Agustín Rojas)")


    nuevo_registro: str = """
## [Día 3] - Ejercicio 03 (Autor: Agustín Rojas)
- Normalización de formatos en columnas de Ubicaciones y Patentes.
- Tratamiento de Inconsistencias: Imputación y manejo de valores nulos.
- Detección y tratamiento de Outliers en el dataset.
"""
    with open("CHANGELOG.md", "a", encoding="utf-8") as f:
        f.write(nuevo_registro)
    print("✅ CHANGELOG.md (raíz) actualizado con el trabajo de Agustín.")


    os.system("git add CHANGELOG.md")
    os.system("git add urban_flow/")


    os.system('git commit -m "feat: Ejercicio 03 - Normalización de ubicaciones,patentes , nulos y outliers por Agustín Rojas"')


    try:
        if not desactivar_git_push and GIT_TOKEN:
            os.system("git push origin Sprint_1")
            print("🚀 ¡Trabajo de Agustín subido con éxito a GitHub!")
        else:
            print("✅ Commit local realizado. El Push está desactivado.")
    except NameError:
         print("⚠️ No se detectaron las variables de entorno de Git. Verifica que la celda de configuración inicial se haya ejecutado.")

commit_agustin_rojas_ejercicio_03()
# Out:
# --- REGISTRANDO APORTE TÉCNICO DE AGUSTÍN ROJAS ---
# ✅ Identidad configurada como ARojas998 (Agustín Rojas)
# ✅ CHANGELOG.md (raíz) actualizado con el trabajo de Agustín.
# 🚀 ¡Trabajo de Agustín subido con éxito a GitHub!

# %%
# Título: Ejercicio 03 - Cálculo de Excesos y Guardado Interim

def finalizar_procesamiento(df: pd.DataFrame) -> None:
  """
  Calcula excesos de velocidad, filtra no infractores y guarda
  el dataset procesado en la carpeta interim.

  Args:
    df (pd.DataFrame): DataFrame limpio y sin outliers.

  Returns:
    None: Guarda el dataset en disco.
  """
  df['exceso_velocidad_real'] = (
    df['velocidad_registrada'] - df['velocidad_maxima']
  )

  print("Primeras 10 patentes y su exceso real:")
  print(df[['patente', 'exceso_velocidad_real']].head(10))
  print("-" * 40)

  df['exceso_velocidad'] = (
    df['velocidad_registrada'] - (df['velocidad_maxima'] * 1.05)
  )

  print("Primeras 10 patentes y su exceso (margen 5%):")
  print(df[['patente', 'exceso_velocidad']].head(10))

  total_inicial: int = len(df)
  df_infractores: pd.DataFrame = df[df['exceso_velocidad'] > 0]
  eliminados: int = total_inicial - len(df_infractores)

  print(f"Se eliminaron {eliminados} filas.")

  ruta_interim: str = "urban_flow/data/interim/speeding_fines.csv"
  os.makedirs("urban_flow/data/interim", exist_ok=True)

  df_infractores.to_csv(ruta_interim, index=False)
  print(f"Dataset guardado en: {ruta_interim}")


finalizar_procesamiento(df_fines_raw)
# Out:
# Primeras 10 patentes y su exceso real:
#     patente  exceso_velocidad_real
# 2    WU341A                   47.0
# 4   BX55DOG                   34.0
# 7     BP717                   10.0
# 9   OUTSTDN                   31.0
# 11  TL03GOG                   -2.0
# 12   GE1466                   35.0
# 16  5777770                   53.0
# 20  BHRP770                   11.0
# 21   RFH373                   41.0
# 23   XIIUME                   12.0
# ----------------------------------------
# Primeras 10 patentes y su exceso (margen 5%):
#     patente  exceso_velocidad
# 2    WU341A              44.0
# 4   BX55DOG              31.0
# 7     BP717               7.0
# 9   OUTSTDN              29.0
# 11  TL03GOG              -4.0
# 12   GE1466              33.0
# 16  5777770              51.0
# 20  BHRP770               8.0
# 21   RFH373              37.0
# 23   XIIUME              10.0
# Se eliminaron 305 filas.
# Dataset guardado en: urban_flow/data/interim/speeding_fines.csv

# %%
ruta_limpia = "urban_flow/data/interim/speeding_fines.csv"
df_infractores_final = pd.read_csv(ruta_limpia)

print(f"Dataset cargado exitosamente. Total de infractores a analizar: {len(df_infractores_final)}")
# Out:
# Dataset cargado exitosamente. Total de infractores a analizar: 1713

# %%
def commit_manu_ejercicio_03_final() -> None:
    print("--- REGISTRANDO CIERRE DEL EJERCICIO 03 POR MANUEL LOMBARDI ---")

    os.system('git config --global user.email "manuellombardi1306@gmail.com"')
    os.system('git config --global user.name "ML13-DEV"')


    nuevo_registro: str = """
## [Día 3] - Ejercicio 03 (Corrección: Manuel Lombardi)
- Implementación de la función `finalizar_procesamiento`.
- Cálculo de excesos de velocidad con margen del 5%.
- Generación y exportación de dataset de infractores a `urban_flow/data/interim/`.
"""
    with open("CHANGELOG.md", "a", encoding="utf-8") as f:
        f.write(nuevo_registro)


    os.system("git add CHANGELOG.md")
    os.system("git add urban_flow/")

    os.system('git commit -m "feat: Ejercicio 03 - Cálculo de excesos y exportación de infractores por Manuel Lombardi"')


    if not desactivar_git_push and GIT_TOKEN:
        os.system("git push origin Sprint_1")
        print(" ¡Trabajo del Ejercicio 03 subido! Sprint 1 avanzado.")
    else:
        print(" Commit local realizado. El Push está desactivado.")

commit_manu_ejercicio_03_final()
# Out:
# --- REGISTRANDO CIERRE DEL EJERCICIO 03 POR MANUEL LOMBARDI ---
#  ¡Trabajo del Ejercicio 03 subido! Sprint 1 avanzado.

# %% [markdown]
# ## Ejercicio 04
#
# > Puntos: 2
#
# Definir una clase FineAnalyzer que cumpla con las siguientes funcionalidades:
#
# - Reciba el DataFrame limpio como argumento de inicialización.
#
# - Encapsule correctamente los datos.
#
# - Implemente métodos para:
#
#   - Ranking de las patentes más multadas (top 5). Debe retornar un DataFrame ordenado de mayor a menor y el índice debe comenzar desde 1, con las columnas de patentes y cantidad..
#
#   - Ranking de los horarios donde se producen más multas (top 5). Debe retornar un DataFrame ordenado de mayor a menor y el índice debe comenzar desde 1, con las columnas de hora y cantidad.
#
#
#   - Exceso promedio de velocidad. Debe retorna un flotante.
#
#   - Exceso real promedio de velocidad . Debe retorna un flotante.
#
#   - Contabilizar la cantidad de multas por cada  ubicación. Debe retornar un DataFrame ordenado por ubicación mostrando la ubicación y la cantidad.
#
# - Crear el objecto e invocar cada uno de los métodos en celdas separadas.

# %%
# Título: Ejercicio 04 - Clase FineAnalyzer (POO)

class FineAnalyzer:
  """
  Clase encargada de realizar análisis estadísticos y rankings
  sobre el dataset de infracciones de velocidad.
  """

  def __init__(self, df: pd.DataFrame) -> None:
    """
    Inicializa la clase encapsulando una copia del DataFrame.

    Args:
      df (pd.DataFrame): Dataset limpio e intermedio de infracciones.

    Returns:
      None: Inicializa el objeto.
    """
    self.__df: pd.DataFrame = df.copy()

  def ranking_patentes(self, n: int = 5) -> pd.DataFrame:
    """
    Genera el ranking de las 'n' patentes con más multas.

        Args:
            n (int): Cantidad de patentes a mostrar en el ranking (default=5).

        Returns:
            pd.DataFrame: DataFrame con columnas 'patente' y 'cantidad',
            ordenado de mayor a menor e índice desde 1.
    """
    ranking: pd.DataFrame = (
      self.__df['patente']
      .value_counts()
      .head(n)
      .rename_axis('patente')
      .reset_index(name='cantidad')
    )

    ranking.index = range(1, len(ranking) + 1)
    return ranking

  def ranking_horarios(self) -> pd.DataFrame:
    """
    Genera el ranking de los 5 horarios con más multas.

    Returns:
      pd.DataFrame: DataFrame con columnas 'hora' y 'cantidad',
      ordenado de mayor a menor e índice desde 1.
    """
    ranking: pd.DataFrame = (
      self.__df['hora']
      .value_counts()
      .head(5)
      .rename_axis('hora')
      .reset_index(name='cantidad')
    )

    ranking.index = range(1, len(ranking) + 1)
    return ranking

  def promedio_exceso_velocidad(self) -> float:
    """
    Calcula el promedio del exceso de velocidad (con margen del 5%).

    Returns:
      float: Promedio del exceso de velocidad.
    """
    return float(self.__df['exceso_velocidad'].mean())

  def promedio_exceso_real(self) -> float:
    """
    Calcula el promedio del exceso de velocidad real (sin margen).

    Returns:
      float: Promedio del exceso real.
    """
    return float(self.__df['exceso_velocidad_real'].mean())

  def multas_por_ubicacion(self) -> pd.DataFrame:
    """
    Cuenta la cantidad de multas por ubicación.

    Returns:
      pd.DataFrame: DataFrame con columnas 'ubicacion' y 'cantidad',
      ordenado alfabéticamente por ubicación.
    """
    conteo: pd.DataFrame = (
      self.__df
      .groupby('ubicacion')
      .size()
      .reset_index(name='cantidad')
    )

    return conteo.sort_values(by='ubicacion')

# %%
# Título: Ejercicio 04 - Inicialización del analizador

analyzer: FineAnalyzer = FineAnalyzer(df_infractores_final)

# %%
# Título: Método - Ranking de las 5 patentes más multadas

top_patentes: pd.DataFrame = analyzer.ranking_patentes()
display(top_patentes)
# Out:
#   patente  cantidad
# 1  WEFLYN        38
# 2  HF3461        37
# 3   T0YDR        36
# 4  M431ZW        34
# 5  AWS167        33

# %%
# Título: Método - Ranking de los 5 horarios con más infracciones

top_horarios: pd.DataFrame = analyzer.ranking_horarios()
display(top_horarios)
# Out:
#     hora  cantidad
# 1  00:00       688
# 2  20:27         5
# 3  18:24         5
# 4  09:04         5
# 5  14:48         5

# %%
# Título: Método - Cálculo de promedios de exceso de velocidad

promedio_real: float = analyzer.promedio_exceso_real()
promedio_margen: float = analyzer.promedio_exceso_velocidad()

print(f"Exceso real promedio: {promedio_real:.2f} km/h")
print(f"Exceso promedio (con margen 5%): {promedio_margen:.2f} km/h")
# Out:
# Exceso real promedio: 42.35 km/h
# Exceso promedio (con margen 5%): 39.32 km/h

# %%
# Título: Método - Cantidad de multas por ubicación

multas_ubicacion: pd.DataFrame = analyzer.multas_por_ubicacion()
display(multas_ubicacion)
# Out:
#          ubicacion  cantidad
# 0    AV LIBERTADOR       708
# 1  AV SIEMPRE VIVA       512
# 2           RUTA 9       493

# %%
def commit_nelson_ejercicio_04() -> None:
    print("--- REGISTRANDO COMMIT DE NELSON: CLASE FINEANALYZER ---")


    os.system('git config --global user.email "castillonelsonramiro3@email.com"')
    os.system('git config --global user.name "NelsonCastillo"')


    registro: str = """
## [Día 3] - Ejercicio 04 (Autor: Nelson Castillo)
- Definición de la clase `FineAnalyzer` mediante Programación Orientada a Objetos (POO).
- Implementación de métodos para rankings (patentes/horarios), promedios y agrupaciones por ubicación.
- Inicialización y ejecución de pruebas de métodos mediante celdas independientes.
"""
    with open("CHANGELOG.md", "a", encoding="utf-8") as f:
        f.write(registro)


    os.system("git add CHANGELOG.md")
    os.system("git add urban_flow/")

    os.system('git commit -m "feat: Ejercicio 04 - Implementación de FineAnalyzer y métodos de análisis por Nelson Castillo"')


    if not desactivar_git_push and GIT_TOKEN:
        os.system("git push origin Sprint_1")
        print(" Clase FineAnalyzer subida exitosamente.")
    else:
        print(" Commit local realizado. El Push está desactivado.")

commit_nelson_ejercicio_04()
# Out:
# --- REGISTRANDO COMMIT DE NELSON: CLASE FINEANALYZER ---
#  Clase FineAnalyzer subida exitosamente.

# %% [markdown]
# ## Punto 05
#
# > Puntos: 2
#
#
# Responder a cada punto con un gráfico.
#
# - Ranking de las 10 patentes más reincidentes ordenadas de mayor a menor. Exportar el gráfico con el nombre `urban_flow/data/interim/plots/fines.jpg`
#
#
# - Mostrar el porcentaje de infracciones por hora en un gráfico de torta. Exportar el gráfico con el nombre `urban_flow/data/interim/plots/hours.jpg`
#
# - Mostrar la cantidad de infracciones por mes en un gráfico de barras horizontal ordenado de mayor a menor. Exportar el gráfico con el nombre `urban_flow/data/interim/plots/months.jpg`
#
# - Mostrar en un gráfico de líneas de los excesos de velocidad agrupados por la hora 00:00. Exportar el gráfico con el nombre `urban_flow/data/interim/plots/hour.jpg`
#
# - Mostrar en un gráfico de líneas de los excesos de velocidad agrupados por la fecha 1932-01-01. Exportar el gráfico con el nombre `urban_flow/data/interim/plots/date.jpg`

# %%
# Título: Punto 05 - Gráfico 1: Top 10 patentes más reincidentes

def graficar_top_patentes(df: pd.DataFrame) -> None:
  """
  Genera y exporta un gráfico de barras con las 10 patentes
  con mayor cantidad de infracciones.

  Args:
    df (pd.DataFrame): DataFrame limpio.

  Returns:
    None: Guarda el gráfico en disco.
  """
  os.makedirs("urban_flow/data/interim/plots", exist_ok=True)

  top_10: pd.Series = (
    df['patente']
    .value_counts()
    .head(10)
    .sort_values(ascending=False)
  )

  plt.figure(figsize=(10, 6))
  top_10.plot(kind='bar')

  plt.title('Top 10 Patentes Más Reincidentes')
  plt.xlabel('Patente')
  plt.ylabel('Cantidad de Infracciones')
  plt.xticks(rotation=45)
  plt.tight_layout()

  ruta: str = "urban_flow/data/interim/plots/fines.jpg"
  plt.savefig(ruta)
  plt.show()
  plt.close()


graficar_top_patentes(df_infractores_final)

# %%
# Título: Punto 05 - Gráfico 2: Porcentaje de infracciones por hora

def graficar_porcentaje_horas(df: pd.DataFrame) -> None:
  """
  Genera un gráfico de torta con el porcentaje de infracciones por hora.
  Para mejorar la legibilidad, se agrupan los registros por hora entera.

  Args:
    df (pd.DataFrame): DataFrame limpio que contiene la columna 'hora'.

  Returns:
    None: Muestra el gráfico y guarda la imagen 'hours.jpg' en disco.
  """
  df_temp: pd.DataFrame = df.copy()

  df_temp['hora_entera'] = pd.to_datetime(
    df_temp['hora'],
    format='%H:%M',
    errors='coerce'
  ).dt.hour


  conteo_horas: pd.Series = (
    df_temp['hora_entera']
    .value_counts()
    .sort_index()
  )

  labels = [f"{int(h):02d}:00" for h in conteo_horas.index]

  plt.figure(figsize=(10, 10))

  plt.pie(
    conteo_horas.values,
    labels=labels,
    autopct='%1.1f%%',
    startangle=140
  )

  plt.title('Porcentaje de Infracciones por Hora')
  plt.tight_layout()

  os.makedirs("urban_flow/data/interim/plots", exist_ok=True)
  ruta: str = "urban_flow/data/interim/plots/hours.jpg"
  plt.savefig(ruta)

  plt.show()
  plt.close()

graficar_porcentaje_horas(df_infractores_final)
# Out:
# (1713, 11)

# %%
def commit_manu_graficos_05() -> None:
    print("--- COMMIT DE MANU: EJERCICIO 05 (GRÁFICOS 1 Y 2) ---")


    os.system('git config --global user.email "manuellombardi1306@gmail.com"')
    os.system('git config --global user.name "ML13-DEV"')


    registro: str = """
## [Día 3] - Ejercicio 05 (Autor: Manuel Lombardi)
- Implementación de `graficar_top_patentes`: Gráfico de barras del Top 10 patentes más reincidentes.
- Implementación de `graficar_porcentaje_horas`: Gráfico de torta con agrupamiento por hora entera.
"""
    with open("CHANGELOG.md", "a", encoding="utf-8") as f:
        f.write(registro)


    os.system("git add CHANGELOG.md")

    os.system("git add urban_flow/")

    os.system('git commit -m "feat: Ejercicio 05 - Implementación de gráficos de patentes y distribución horaria por Manuel Lombardi"')


    if not desactivar_git_push and GIT_TOKEN:
        os.system("git push origin Sprint_1")
        print("Gráficos 1 y 2 subidos exitosamente.")
    else:
        print("Commit local realizado. El Push está desactivado.")

commit_manu_graficos_05()
# Out:
# --- COMMIT DE MANU: EJERCICIO 05 (GRÁFICOS 1 Y 2) ---
# Gráficos 1 y 2 subidos exitosamente.

# %%
# Título: Punto 05 - Gráfico 3: Cantidad de infracciones por mes

def graficar_infracciones_mes(df: pd.DataFrame) -> None:
  """
  Genera y exporta un gráfico de barras horizontal ordenado de
  mayor a menor con las infracciones agrupadas por mes.

  Args:
    df (pd.DataFrame): DataFrame limpio.

  Returns:
    None: Guarda el gráfico en disco.
  """
  os.makedirs("urban_flow/data/interim/plots", exist_ok=True)

  df_temp: pd.DataFrame = df.copy()
  df_temp['mes'] = pd.to_datetime(
    df_temp['fecha'], errors='coerce'
  ).dt.month

  conteo_meses: pd.Series = (
    df_temp['mes']
    .value_counts()
    .sort_values(ascending=True)
  )

  plt.figure(figsize=(10, 6))
  conteo_meses.plot(kind='barh')

  plt.title('Cantidad de Infracciones por Mes')
  plt.xlabel('Cantidad de Infracciones')
  plt.ylabel('Mes (Número)')
  plt.tight_layout()

  ruta: str = "urban_flow/data/interim/plots/months.jpg"
  plt.savefig(ruta)
  plt.show()
  plt.close()


graficar_infracciones_mes(df_infractores_final)

# %%
# Título: Punto 05 - Gráfico 4: Excesos de velocidad (Hora 00:00)

def graficar_excesos_hora_cero(df: pd.DataFrame) -> None:
  """
  Genera y exporta un gráfico de líneas agrupando la cantidad
  de infractores por cada exceso de velocidad a la hora 00:00.

  Args:
    df (pd.DataFrame): DataFrame limpio (df_infractores_final).

  Returns:
    None: Guarda el gráfico en disco.
  """
  os.makedirs("urban_flow/data/interim/plots", exist_ok=True)

  df_hora: pd.DataFrame = df[df['hora'] == '00:00'].copy()

  if df_hora.empty:
    print("No hay registros para la hora 00:00.")
    return


  df_agrupado = df_hora.groupby('exceso_velocidad').size()

  plt.figure(figsize=(12, 5))

  plt.plot(df_agrupado.index, df_agrupado.values, color='tab:blue', marker='o')

  plt.title('Cantidad de Infractores por Exceso de Velocidad a las 00:00')
  plt.xlabel('Exceso de Velocidad (km/h)')
  plt.ylabel('Cantidad de Infractores')
  plt.grid(True, linestyle='--', alpha=0.6)
  plt.tight_layout()

  ruta: str = "urban_flow/data/interim/plots/hour.jpg"
  plt.savefig(ruta)
  plt.show()
  plt.close()


graficar_excesos_hora_cero(df_infractores_final)

# %%
# Título: Punto 05 - Gráfico 5: Excesos de velocidad (Fecha 1932-01-01)

def graficar_excesos_fecha_error(df: pd.DataFrame) -> None:
  """
  Genera y exporta un gráfico de líneas agrupando la cantidad
  de infractores por cada exceso de velocidad en la fecha 1932-01-01.

  Args:
    df (pd.DataFrame): DataFrame limpio (df_infractores_final).
  """

  os.makedirs("urban_flow/data/interim/plots", exist_ok=True)


  df_fecha: pd.DataFrame = df[df['fecha'] == '1932-01-01'].copy()

  if df_fecha.empty:
    print("No hay registros para la fecha 1932-01-01. Revisa si el formato es correcto.")
    return


  df_agrupado = df_fecha.groupby('exceso_velocidad').size()


  plt.figure(figsize=(12, 5))


  plt.plot(df_agrupado.index, df_agrupado.values, color='tab:green', marker='o', linestyle='-')

  plt.title('Cantidad de Infractores por Exceso de Velocidad (Fecha 1932-01-01)')
  plt.xlabel('Exceso de Velocidad (km/h)')
  plt.ylabel('Cantidad de Infractores')
  plt.grid(True, linestyle='--', alpha=0.6)
  plt.tight_layout()

  ruta: str = "urban_flow/data/interim/plots/date.jpg"
  plt.savefig(ruta)


  plt.show()


graficar_excesos_fecha_error(df_infractores_final)

# %% [markdown]
# ## Punto 06
#
# > Puntos: 1
#
# - Mostrar el porcentaje de infracción que se produjeron en la fecha 1932-01-01.
#
# ```
# El porcentaje de infracciones en la fecha 1932-01-01 es XX.XX%
# ```
#
# - Mostrar el porcentaje de infracción que se produjeron en la hora 00:00.
# ```
# El porcentaje de infracciones a la hora 00:00 es XX.XX%
# ```

# %% [markdown]
# ## Punto 07
#
# > Puntos: 1
#
#
#
# Redactar una conclusión acerca de los datos que contiene el dataset.

# %%
# %%writefile -a data/Readme.md
